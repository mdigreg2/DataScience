# %% [markdown]
# <h3>Pandas' series type can be used to make a flexible python list. Data referencing works like it does with numpy arrays. Named variables seem to be references to the same data, which is why you can cange one reference by changing another. This saves on space and computing resources. See the last three lines for this example</h3>

# %%
# An important part of pandas is "series" They are built off of python lists bu are much more flexible

import pandas as pd
import numpy as np

s = pd.Series(np.random.randn(4), name = 'daily returns')
print(s)

s.index = ['AMAZN', 'GOOGL','WISA','CITI']
print(s)

print(s.describe())
print(s * 100)
print(s['AMAZN'])
s['AMAZN'] = 0
print(s)
b = s
b['GOOGL'] = 100
print(s)
# Out:
# 0    0.448884
# 1   -1.720809
# 2   -0.603493
# 3    0.038673
# Name: daily returns, dtype: float64
# AMAZN    0.448884
# GOOGL   -1.720809
# WISA    -0.603493
# CITI     0.038673
# Name: daily returns, dtype: float64
# count    4.000000
# mean    -0.459186
# std      0.946039
# min     -1.720809
# 25%     -0.882822
# 50%     -0.282410
# 75%      0.141226
# max      0.448884
# Name: daily returns, dtype: float64
# AMAZN     44.888394
# GOOGL   -172.080858
# WISA     -60.349306
# CITI       3.867291
# Name: daily returns, dtype: float64
# 0.448883940356
# AMAZN    0.000000
# GOOGL   -1.720809
# WISA    -0.603493
# CITI     0.038673
# Name: daily returns, dtype: float64
# AMAZN      0.000000
# GOOGL    100.000000
# WISA      -0.603493
# CITI       0.038673
# Name: daily returns, dtype: float64

# %% [markdown]
# <h3>Data frames are multi-dimensional versions of pandas series</h3>

# %%
# while a series is a single column of data, a Data Frame is multiple columns of data akin to an excel spreadsheet
# One column per variable
import pandas as pd
import numpy as np

df = pd.read_csv('../data/Demographic_Statistics_By_Zip_Code.csv')
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 0                10001                  44            22            0.50
# 1                10002                  35            19            0.54
# 2                10003                   1             1            1.00
# 3                10004                   0             0            0.00
# 4                10005                   2             2            1.00
# 5                10006                   6             2            0.33
# 6                10007                   1             0            0.00
# 7                10009                   2             0            0.00
# 8                10010                   0             0            0.00
# 9                10011                   3             2            0.67
# 10               10012                   0             0            0.00
# ...

# %%
# we can also use standard python array slicing notation to describe rows and columns
import pandas as pd
import numpy as np

df = pd.read_csv('../data/Demographic_Statistics_By_Zip_Code.csv')
df[2:5]
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE  \
# 2              10003                   1             1             1.0
# 3              10004                   0             0             0.0
# 4              10005                   2             2             1.0
#
#    COUNT MALE  PERCENT MALE  COUNT GENDER UNKNOWN  PERCENT GENDER UNKNOWN  \
# 2           0           0.0                     0                       0
# 3           0           0.0                     0                       0
# 4           0           0.0                     0                       0
#
#    COUNT GENDER TOTAL  PERCENT GENDER TOTAL  ...  COUNT CITIZEN STATUS TOTAL  \
# 2                   1                   100  ...                           1
# 3                   0                     0  ...                           0
# 4                   2                   100  ...                           2
#
#    PERCENT CITIZEN STATUS TOTAL  COUNT RECEIVES PUBLIC ASSISTANCE  \
# ...

# %% [markdown]
# <h3>Individual columns can be filtered out using pandas</h3>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/Demographic_Statistics_By_Zip_Code.csv')
df[['JURISDICTION NAME', 'PERCENT MALE']]
# Out:
#      JURISDICTION NAME  PERCENT MALE
# 0                10001          0.50
# 1                10002          0.46
# 2                10003          0.00
# 3                10004          0.00
# 4                10005          0.00
# 5                10006          0.67
# 6                10007          1.00
# 7                10009          1.00
# 8                10010          0.00
# 9                10011          0.33
# 10               10012          0.00
# 11               10013          0.88
# 12               10014          0.00
# 13               10016          0.29
# 14               10017          0.00
# 15               10018          0.33
# 16               10019          0.00
# 17               10020          0.00
# 18               10021          0.00
# 19               10022          0.00
# 20               10023          0.29
# 21               10024          0.00
# 22               10025          0.37
# 23               10026          0.00
# ...

# %% [markdown]
# <h3>Rows and columns can be selected using python list notation and the .iloc method (integers)</h3>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/Demographic_Statistics_By_Zip_Code.csv')
# can select rows and columns using integers, .iloc[rows,columns]
df.iloc[2:5, 0:4]
# Out:
#    JURISDICTION NAME  COUNT PARTICIPANTS  COUNT FEMALE  PERCENT FEMALE
# 2              10003                   1             1             1.0
# 3              10004                   0             0             0.0
# 4              10005                   2             2             1.0

# %% [markdown]
# <h3>Columns can also be selected using the heading name</h3>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../data/Demographic_Statistics_By_Zip_Code.csv')

df.loc[df.index[0:5], ['COUNT FEMALE', 'PERCENT FEMALE']]
# Out:
#    COUNT FEMALE  PERCENT FEMALE
# 0            22            0.50
# 1            19            0.54
# 2             1            1.00
# 3             0            0.00
# 4             2            1.00

# %% [markdown]
# <h3>Individual features can be graphed and new ones created by simply labeling another column and populating it</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
# %matplotlib inline

df = pd.read_csv('../data/Demographic_Statistics_By_Zip_Code.csv')

df = df.loc[df.index[0:10], ['JURISDICTION NAME', 'COUNT MALE', 'COUNT FEMALE', 'COUNT CITIZEN STATUS TOTAL']]
df.columns = 'Jurisdiction', 'Male', 'Female', 'Total'
df['Ratio'] = df['Male'] / df['Female']
df['Male'].plot(kind = 'bar')
pt.show()

# %% [markdown]
# <h3>Data can also be sorted within the program using pandas' sort_values() method</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
# %matplotlib inline

df = pd.read_csv('../data/Demographic_Statistics_By_Zip_Code.csv')

df = df.loc[df.index[0:10], ['JURISDICTION NAME', 'COUNT MALE', 'COUNT FEMALE', 'COUNT CITIZEN STATUS TOTAL']]
df.columns = 'Jurisdiction', 'Male', 'Female', 'Total'
df['Ratio'] = df['Male'] / df['Female']
df = df.sort_values(by = 'Male', ascending=False)
df['Male'].plot(kind = 'bar')
pt.show()

# %% [markdown]
# <h3>Data can also be sourced from online</h3>

# %%
# A test to make sure that the request works, no error means that it works
import requests

r = requests.get('http://research.stlouisfed.org/fred2/series/UNRATE/downloaddata/UNRATE.csv')

# %% [markdown]
# <h3>Using FRED unemployment data:</h3>

# %%
import requests
import pandas as pd
import matplotlib.pyplot as pt
# %matplotlib inline

url = 'http://research.stlouisfed.org/fred2/series/UNRATE/downloaddata/UNRATE.csv'
source = requests.get(url).content.decode().split("\n")
print(source[0])
print(source[1])
print(source[2])
# using pandas' parse dates function will automatically recognize the dates in the file
data = pd.read_csv(url, index_col = 0, parse_dates = True)
# data.head() is a useful way to get some quick info from a csv
data.head()
# set option allows you to set the decimal precision of the calculations in pd.describe() if you set precision to 10 you get 
# 10 decimal places
pd.set_option('precision', 1)
data.describe()

# pandas csv data can also use a .plot() method to quickly plot itself

data['2000':'2012'].plot()
# Out:
# DATE,VALUE
# 1948-01-01,3.4
# 1948-02-01,3.8

# %% [markdown]
# <h3>Using World Bank debt data: </h3>

# %%
import pandas as pd
import matplotlib.pyplot as pt
import requests
# %matplotlib inline


# get data and read into the file gd.xls
url = "http://api.worldbank.org/v2/en/indicator/gc.dod.totl.gd.zs?downloadformat=excel"
r = requests.get(url)
with open('gd.xls', 'wb') as output:
    output.write(r.content)

# put the data into a data frame
govtDebt = pd.read_excel('gd.xls', sheet_name = 'Data', skiprows = 3, index_col = 1)
govtDebt = govtDebt.transpose()
govtDebt = govtDebt[['AUS', 'USA']]
govtDebt = govtDebt[30:]
govtDebt.plot(lw = 2, alpha = .6)
pt.show()


# the .transpose() function reverses rows and columns. i.e. rows become columns and columns become rows

# %% [markdown]
# <h3>The following will take stock ticker data from 9 companies and 9 different files and compile them into one smaller list. This is a good example for why Python passing around references to the same data is advantageous. Copying these data sets 15 times each would be prohibitively expensive computationally</h3>

# %%
# AAL, ADM, BXP, CMI, CVS, FDX, EQIX, EQT, GOOG, MSI, NVDA, UPS
# # -- date -- open -- high -- low -- close -- volume -- Name
import pandas as pd
import matplotlib.pyplot as pt
import matplotlib.dates as mdates
import numpy as np
# %matplotlib inline

tickerList = ('AAL', 'ADM', 'BXP', 'CMI', 'CVS', 'FDX', 'EQIX', 'EQT', 'GOOG')

#tickers = [AAL_raw,ADM_raw,BXP_raw,CMI_raw,CVS_raw,FDX_raw,EQIX_raw,EQT_raw,GOOG_raw,MSI_raw,NVDA_raw,UPS_raw]
# dfTest = pd.read_csv('/home/mycicle/localDatasets/individual_stocks_5yr/individual_stocks_5yr/UPS_data.csv')
# dfTest = dfTest[0:10]
tickers = []
years = []
dates = []
for i in tickerList:
    tickers.append(1)
    years.append(1)
    dates.append(1)

for index, names in enumerate(tickerList):
    tickers[index] = pd.read_csv('/home/mycicle/localDatasets/individual_stocks_5yr/individual_stocks_5yr/' + f'{names}' + str('_data.csv'))

    
AAL_raw = tickers[0]
ADM_raw = tickers[1]
BXP_raw = tickers[2]
CMI_raw = tickers[3]
CVS_raw = tickers[4]
FDX_raw = tickers[5]
EQIX_raw = tickers[6]
EQT_raw = tickers[7]
GOOG_raw = tickers[8]



# now onto graphing the opening prices 

for index, opening in enumerate(tickers):
    tickers[index] = tickers[index][['date', 'open']]
    dates[index] = tickers[index]['date']
    
# for index, i in enumerate(dates):
#     years[index] = dates[index]
    
# for index, i in enumerate(years):
#     years[index] = years[index][0:4]


    
rows, columns = 3,3
n = 0
fig,axes = plt.subplots(rows,columns,figsize = (10,12))
for i in range(rows):
    for j in range(columns):
        currentLabel = tickerList[n]
        print(currentLabel)
        x = tickers[n]['date'][-100:]
        y = tickers[n]['open'][-100:]
        axes[i,j].plot(x,y,linewidth = 2, alpha = .6)
        axes[i,j].legend( [currentLabel], loc = 'upper right',)
        axes[i,j].set_title(currentLabel)
        axes[i,j].set_xticklabels([])
        n+=1
        
n = 0
for i in range(0,rows,10):
    for j in range(0,columns,10):
        pt.setp(axes[i,j].xaxis.get_majorticklabels(), rotation = 70)
        n+=1
        
fig.set_size_inches(18.5,10.5)
fig.autofmt_xdate()

pt.show()
# g = years[0][0:4]
# g[0][0:4]
# Out:
# AAL
# ADM
# BXP
# CMI
# CVS
# FDX
# EQIX
# EQT
# GOOG

# %% [markdown]
# <h3>Ignore this, it is scrap</h3>

# %%
for i in range(rows):
    for j in range(columns):
        x = np.array(tickers[index][['date']][5:])
        y = np.array(tickers[index][['open']][5:])
        ax[i,j].plot(x,y,linewidth = 2, alpha = .6, label = tickerList[index])
        ax[i,j].set_title(tickerList[index])
        index += 1
pt.legend(loc = 'lower left')
pt.show()

# format ticks
ax.xaxis.set_major_locator(years)
ax.xaxis.set_major_formatter(years_fmt)
ax.xaxis.set_minor_locator(months)


print(tickers[10]['date'][-1:])
# pt.show()
# round to the nearest year
datemin = np.datetime64(tickers[10]['date'][0], 'Y')
datemax = np.datetime64(tickers[10]['date'][-1:], 'Y') + np.timedelta64(1, 'Y')
ax.set_xlim(datemin, datemax)

ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
ax.format_ydata = lambda x: '$1.2f' % x                 #format price
ax.grid(True)

fig.autofmt_xdate()
pt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')

# Load a numpy structured array from yahoo csv data with fields date, open,
# close, volume, adj_close from the mpl-data/example directory.  This array
# stores the date as an np.datetime64 with a day unit ('D') in the 'date'
# column.
# with cbook.get_sample_data('goog.npz') as datafile:
#     data = np.load(datafile)['price_data']

data = pd.read_csv('/home/mycicle/localDatasets/individual_stocks_5yr/individual_stocks_5yr/GOOG_data.csv')

data = data['date']
year = np.empty(len(data))
for index,i in enumerate(data):
    year[index] = data[index][0:4]

counter = 0
first = True
currentYear = year[0]
previousYear = year[0]
for index,i in enumerate(year):
    currentYear = year[index]
    if(currentYear != previousYear or first == True):
        print(currentYear)
        first = False
        counter+=1
    previousYear = currentYear
# Out:
# 2014.0
# 2015.0
# 2016.0
# 2017.0
# 2018.0
# [2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
#  2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014. 2014.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
# %matplotlib inline



data = pd.read_csv('/home/mycicle/localDatasets/individual_stocks_5yr/individual_stocks_5yr/GOOG_data.csv')
tickers = data[['date','open']]
data = data['date']
year = np.empty(len(data))
for index,i in enumerate(data):
    year[index] = data[index][0:4]

counter = 0
first = True
currentYear = year[0]
previousYear = year[0]
for index,i in enumerate(year):
    currentYear = year[index]
    if(currentYear != previousYear or first == True):
        print(currentYear)
        first = False
        counter+=1
    else:
        year[index] = 0
    previousYear = currentYear
    
xaxis = []
for index,i in enumerate(year):
    if(year[index] != 0):
        xaxis.append(year[index])
    else:
        xaxis.append("")

fix, ax = pt.subplots()
x = tickers['date']
y = tickers['open']
ax.plot(x, y, alpha = .6)
ax.set_xticklabels(xaxis)
pt.setp(ax.xaxis.get_majorticklabels(), rotation = 70)
pt.show()
# Out:
# 2014.0
# 2015.0
# 2016.0
# 2017.0
# 2018.0

# %%
ticker[0] = 10
ticker[1] = 20
print(ticker)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-85199fb26989> in <module>
# ----> 1 ticker[0] = 10
#       2 ticker[1] = 20
#       3 print(ticker)
#
# NameError: name 'ticker' is not defined
