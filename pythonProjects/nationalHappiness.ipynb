# %% [markdown]
# This will be a simple machine learning algorithm to predict the happiness of nations based on GDP per capita
# It will use k-nearest neighbor
# It is based off of an example from "Hands On Machine Learning with Scikit-Learn and Tensorflow" by Aurelien Geron

# %%
import matplotlib
import matplotlib.pyplot as pt
import pandas as pd
import numpy as np
import sklearn.linear_model as skll

# OCED better life index https://stats.oecd.org/index.aspx?DataSetCode=BLI
# IMF GDP data https://www.imf.org/external/pubs/ft/weo/2016/01/weodata/weorept.aspx?pr.x=32&pr.y=8&sy=2015&ey=2015&scsm=1&ssd=1&sort=country&ds=.&br=1&c=512%2C668%2C914%2C672%2C612%2C946%2C614%2C137%2C311%2C962%2C213%2C674%2C911%2C676%2C193%2C548%2C122%2C556%2C912%2C678%2C313%2C181%2C419%2C867%2C513%2C682%2C316%2C684%2C913%2C273%2C124%2C868%2C339%2C921%2C638%2C948%2C514%2C943%2C218%2C686%2C963%2C688%2C616%2C518%2C223%2C728%2C516%2C558%2C918%2C138%2C748%2C196%2C618%2C278%2C624%2C692%2C522%2C694%2C622%2C142%2C156%2C449%2C626%2C564%2C628%2C565%2C228%2C283%2C924%2C853%2C233%2C288%2C632%2C293%2C636%2C566%2C634%2C964%2C238%2C182%2C662%2C453%2C960%2C968%2C423%2C922%2C935%2C714%2C128%2C862%2C611%2C135%2C321%2C716%2C243%2C456%2C248%2C722%2C469%2C942%2C253%2C718%2C642%2C724%2C643%2C576%2C939%2C936%2C644%2C961%2C819%2C813%2C172%2C199%2C132%2C733%2C646%2C184%2C648%2C524%2C915%2C361%2C134%2C362%2C652%2C364%2C174%2C732%2C328%2C366%2C258%2C734%2C656%2C144%2C654%2C146%2C336%2C463%2C263%2C528%2C268%2C923%2C532%2C738%2C944%2C578%2C176%2C537%2C534%2C742%2C536%2C866%2C429%2C369%2C433%2C744%2C178%2C186%2C436%2C925%2C136%2C869%2C343%2C746%2C158%2C926%2C439%2C466%2C916%2C112%2C664%2C111%2C826%2C298%2C542%2C927%2C967%2C846%2C443%2C299%2C917%2C582%2C544%2C474%2C941%2C754%2C446%2C698%2C666&s=NGDPDPC&grp=0&a=


# load the data
ocedBli = pd.read_csv("/home/mycicle/git/DataScience/data/oced-bli.csv", thousands = ',')
print(ocedBli)
imfGdp = pd.read_excel
# Out:
#      LOCATION          Country INDICATOR                          Indicator  \
# 0         AUS        Australia   JE_LMIS           Labour market insecurity
# 1         AUT          Austria   JE_LMIS           Labour market insecurity
# 2         BEL          Belgium   JE_LMIS           Labour market insecurity
# 3         CAN           Canada   JE_LMIS           Labour market insecurity
# 4         CZE   Czech Republic   JE_LMIS           Labour market insecurity
# 5         DNK          Denmark   JE_LMIS           Labour market insecurity
# 6         FIN          Finland   JE_LMIS           Labour market insecurity
# 7         FRA           France   JE_LMIS           Labour market insecurity
# 8         DEU          Germany   JE_LMIS           Labour market insecurity
# 9         GRC           Greece   JE_LMIS           Labour market insecurity
# 10        HUN          Hungary   JE_LMIS           Labour market insecurity
# 11        ISL          Iceland   JE_LMIS           Labour market insecurity
# 12        IRL          Ireland   JE_LMIS           Labour market insecurity
# 13        ITA            Italy   JE_LMIS           Labour market insecurity
# 14        JPN            Japan   JE_LMIS           Labour market insecurity
# 15        KOR            Korea   JE_LMIS           Labour market insecurity
# 16        LUX       Luxembourg   JE_LMIS           Labour market insecurity
# 17        MEX           Mexico   JE_LMIS           Labour market insecurity
# 18        NLD      Netherlands   JE_LMIS           Labour market insecurity
# 19        NZL      New Zealand   JE_LMIS           Labour market insecurity
# 20        POL           Poland   JE_LMIS           Labour market insecurity
# 21        PRT         Portugal   JE_LMIS           Labour market insecurity
# 22        SVK  Slovak Republic   JE_LMIS           Labour market insecurity
# 23        ESP            Spain   JE_LMIS           Labour market insecurity
# 24        SWE           Sweden   JE_LMIS           Labour market insecurity
# 25        TUR           Turkey   JE_LMIS           Labour market insecurity
# 26        GBR   United Kingdom   JE_LMIS           Labour market insecurity
# 27        USA    United States   JE_LMIS           Labour market insecurity
# 28        CHL            Chile   JE_LMIS           Labour market insecurity
# 29        EST          Estonia   JE_LMIS           Labour market insecurity
# ...       ...              ...       ...                                ...
# 2338      LTU        Lithuania    HS_LEB                    Life expectancy
# 2339      COL         Colombia    HS_LEB                    Life expectancy
# 2340      LTU        Lithuania    HS_LEB                    Life expectancy
# 2341      COL         Colombia    HS_LEB                    Life expectancy
# 2342      LTU        Lithuania    HS_LEB                    Life expectancy
# 2343      LTU        Lithuania   HS_SFRH               Self-reported health
# 2344      LTU        Lithuania   HS_SFRH               Self-reported health
# 2345      LTU        Lithuania   HS_SFRH               Self-reported health
# 2346      LTU        Lithuania   HS_SFRH               Self-reported health
# 2347      LTU        Lithuania   HS_SFRH               Self-reported health
# 2348      COL         Colombia   SW_LIFS                  Life satisfaction
# 2349      LTU        Lithuania   SW_LIFS                  Life satisfaction
# 2350      COL         Colombia   SW_LIFS                  Life satisfaction
# 2351      LTU        Lithuania   SW_LIFS                  Life satisfaction
# 2352      COL         Colombia   SW_LIFS                  Life satisfaction
# 2353      LTU        Lithuania   SW_LIFS                  Life satisfaction
# 2354      LTU        Lithuania   SW_LIFS                  Life satisfaction
# 2355      LTU        Lithuania   SW_LIFS                  Life satisfaction
# 2356      COL         Colombia   PS_REPH                      Homicide rate
# 2357      LTU        Lithuania   PS_REPH                      Homicide rate
# 2358      COL         Colombia   PS_REPH                      Homicide rate
# 2359      LTU        Lithuania   PS_REPH                      Homicide rate
# 2360      COL         Colombia   PS_REPH                      Homicide rate
# 2361      LTU        Lithuania   PS_REPH                      Homicide rate
# 2362      COL         Colombia   WL_EWLH  Employees working very long hours
# 2363      LTU        Lithuania   WL_EWLH  Employees working very long hours
# 2364      COL         Colombia   WL_EWLH  Employees working very long hours
# 2365      LTU        Lithuania   WL_EWLH  Employees working very long hours
# 2366      COL         Colombia   WL_EWLH  Employees working very long hours
# 2367      LTU        Lithuania   WL_EWLH  Employees working very long hours
#
#      MEASURE Measure INEQUALITY Inequality Unit Code           Unit  \
# 0          L   Value        TOT      Total        PC     Percentage
# 1          L   Value        TOT      Total        PC     Percentage
# 2          L   Value        TOT      Total        PC     Percentage
# 3          L   Value        TOT      Total        PC     Percentage
# 4          L   Value        TOT      Total        PC     Percentage
# 5          L   Value        TOT      Total        PC     Percentage
# 6          L   Value        TOT      Total        PC     Percentage
# 7          L   Value        TOT      Total        PC     Percentage
# 8          L   Value        TOT      Total        PC     Percentage
# 9          L   Value        TOT      Total        PC     Percentage
# 10         L   Value        TOT      Total        PC     Percentage
# 11         L   Value        TOT      Total        PC     Percentage
# 12         L   Value        TOT      Total        PC     Percentage
# 13         L   Value        TOT      Total        PC     Percentage
# 14         L   Value        TOT      Total        PC     Percentage
# 15         L   Value        TOT      Total        PC     Percentage
# 16         L   Value        TOT      Total        PC     Percentage
# 17         L   Value        TOT      Total        PC     Percentage
# 18         L   Value        TOT      Total        PC     Percentage
# 19         L   Value        TOT      Total        PC     Percentage
# 20         L   Value        TOT      Total        PC     Percentage
# 21         L   Value        TOT      Total        PC     Percentage
# 22         L   Value        TOT      Total        PC     Percentage
# 23         L   Value        TOT      Total        PC     Percentage
# 24         L   Value        TOT      Total        PC     Percentage
# 25         L   Value        TOT      Total        PC     Percentage
# 26         L   Value        TOT      Total        PC     Percentage
# 27         L   Value        TOT      Total        PC     Percentage
# 28         L   Value        TOT      Total        PC     Percentage
# 29         L   Value        TOT      Total        PC     Percentage
# ...      ...     ...        ...        ...       ...            ...
# 2338       L   Value        TOT      Total        YR          Years
# 2339       L   Value         MN        Men        YR          Years
# 2340       L   Value         MN        Men        YR          Years
# 2341       L   Value        WMN      Women        YR          Years
# 2342       L   Value        WMN      Women        YR          Years
# 2343       L   Value        TOT      Total        PC     Percentage
# 2344       L   Value         MN        Men        PC     Percentage
# 2345       L   Value        WMN      Women        PC     Percentage
# 2346       L   Value        HGH       High        PC     Percentage
# 2347       L   Value         LW        Low        PC     Percentage
# 2348       L   Value        TOT      Total   AVSCORE  Average score
# 2349       L   Value        TOT      Total   AVSCORE  Average score
# 2350       L   Value         MN        Men   AVSCORE  Average score
# 2351       L   Value         MN        Men   AVSCORE  Average score
# 2352       L   Value        WMN      Women   AVSCORE  Average score
# 2353       L   Value        WMN      Women   AVSCORE  Average score
# 2354       L   Value        HGH       High   AVSCORE  Average score
# 2355       L   Value         LW        Low   AVSCORE  Average score
# 2356       L   Value        TOT      Total     RATIO          Ratio
# 2357       L   Value        TOT      Total     RATIO          Ratio
# 2358       L   Value         MN        Men     RATIO          Ratio
# 2359       L   Value         MN        Men     RATIO          Ratio
# 2360       L   Value        WMN      Women     RATIO          Ratio
# 2361       L   Value        WMN      Women     RATIO          Ratio
# 2362       L   Value        TOT      Total        PC     Percentage
# 2363       L   Value        TOT      Total        PC     Percentage
# 2364       L   Value         MN        Men        PC     Percentage
# 2365       L   Value         MN        Men        PC     Percentage
# 2366       L   Value        WMN      Women        PC     Percentage
# 2367       L   Value        WMN      Women        PC     Percentage
#
#       PowerCode Code PowerCode  Reference Period Code  Reference Period  \
# 0                  0     Units                    NaN               NaN
# 1                  0     Units                    NaN               NaN
# 2                  0     Units                    NaN               NaN
# 3                  0     Units                    NaN               NaN
# 4                  0     Units                    NaN               NaN
# 5                  0     Units                    NaN               NaN
# 6                  0     Units                    NaN               NaN
# 7                  0     Units                    NaN               NaN
# 8                  0     Units                    NaN               NaN
# 9                  0     Units                    NaN               NaN
# 10                 0     Units                    NaN               NaN
# 11                 0     Units                    NaN               NaN
# 12                 0     Units                    NaN               NaN
# 13                 0     Units                    NaN               NaN
# 14                 0     Units                    NaN               NaN
# 15                 0     Units                    NaN               NaN
# 16                 0     Units                    NaN               NaN
# 17                 0     Units                    NaN               NaN
# 18                 0     Units                    NaN               NaN
# 19                 0     Units                    NaN               NaN
# 20                 0     Units                    NaN               NaN
# 21                 0     Units                    NaN               NaN
# 22                 0     Units                    NaN               NaN
# 23                 0     Units                    NaN               NaN
# 24                 0     Units                    NaN               NaN
# 25                 0     Units                    NaN               NaN
# 26                 0     Units                    NaN               NaN
# 27                 0     Units                    NaN               NaN
# 28                 0     Units                    NaN               NaN
# 29                 0     Units                    NaN               NaN
# ...              ...       ...                    ...               ...
# 2338               0     Units                    NaN               NaN
# 2339               0     Units                    NaN               NaN
# 2340               0     Units                    NaN               NaN
# 2341               0     Units                    NaN               NaN
# 2342               0     Units                    NaN               NaN
# 2343               0     Units                    NaN               NaN
# 2344               0     Units                    NaN               NaN
# 2345               0     Units                    NaN               NaN
# 2346               0     Units                    NaN               NaN
# 2347               0     Units                    NaN               NaN
# 2348               0     Units                    NaN               NaN
# 2349               0     Units                    NaN               NaN
# 2350               0     Units                    NaN               NaN
# 2351               0     Units                    NaN               NaN
# 2352               0     Units                    NaN               NaN
# 2353               0     Units                    NaN               NaN
# 2354               0     Units                    NaN               NaN
# 2355               0     Units                    NaN               NaN
# 2356               0     Units                    NaN               NaN
# 2357               0     Units                    NaN               NaN
# 2358               0     Units                    NaN               NaN
# 2359               0     Units                    NaN               NaN
# 2360               0     Units                    NaN               NaN
# 2361               0     Units                    NaN               NaN
# 2362               0     Units                    NaN               NaN
# 2363               0     Units                    NaN               NaN
# 2364               0     Units                    NaN               NaN
# 2365               0     Units                    NaN               NaN
# 2366               0     Units                    NaN               NaN
# 2367               0     Units                    NaN               NaN
#
#       Value  Flag Codes  Flags
# 0      5.40         NaN    NaN
# 1      3.50         NaN    NaN
# 2      3.70         NaN    NaN
# 3      6.00         NaN    NaN
# 4      3.10         NaN    NaN
# 5      4.20         NaN    NaN
# 6      3.90         NaN    NaN
# 7      7.60         NaN    NaN
# 8      2.70         NaN    NaN
# 9     29.80         NaN    NaN
# 10     4.70         NaN    NaN
# 11     0.70         NaN    NaN
# 12     7.80         NaN    NaN
# 13    12.30         NaN    NaN
# 14     1.40         NaN    NaN
# 15     2.60         NaN    NaN
# 16     1.70         NaN    NaN
# 17     5.50         NaN    NaN
# 18     4.80         NaN    NaN
# 19     4.70         NaN    NaN
# 20     5.70         NaN    NaN
# 21    10.00         NaN    NaN
# 22     9.90         NaN    NaN
# 23    23.10         NaN    NaN
# 24     3.20         NaN    NaN
# 25    12.50         NaN    NaN
# 26     4.50         NaN    NaN
# 27     7.70         NaN    NaN
# 28     8.70         NaN    NaN
# 29     3.80         NaN    NaN
# ...     ...         ...    ...
# 2338  74.80         NaN    NaN
# 2339  73.10         NaN    NaN
# 2340  69.50         NaN    NaN
# 2341  79.40         NaN    NaN
# 2342  80.10         NaN    NaN
# 2343  43.00         NaN    NaN
# 2344  49.00         NaN    NaN
# 2345  40.00         NaN    NaN
# 2346  67.00         NaN    NaN
# 2347  29.00         NaN    NaN
# 2348   6.30         NaN    NaN
# 2349   5.90         NaN    NaN
# 2350   6.20         NaN    NaN
# 2351   5.90         NaN    NaN
# 2352   6.30         NaN    NaN
# 2353   6.00         NaN    NaN
# 2354   6.50         NaN    NaN
# 2355   5.60         NaN    NaN
# 2356  24.50         NaN    NaN
# 2357   3.40         NaN    NaN
# 2358  46.40         NaN    NaN
# 2359   5.20         NaN    NaN
# 2360   4.10         NaN    NaN
# 2361   1.70         NaN    NaN
# 2362  26.56         NaN    NaN
# 2363   0.54         NaN    NaN
# 2364  32.09         NaN    NaN
# 2365   0.67         NaN    NaN
# 2366  19.37         NaN    NaN
# 2367   0.43         NaN    NaN
#
# [2368 rows x 17 columns]
